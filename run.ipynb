# %%
# !pip install transformers
# !pip install tensorboard
# !pip install quickspacer
# Out:
# ...
#      |████████████████████████████████| 4.0 MB 14.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 596 kB 57.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 77 kB 8.4 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 880 kB 77.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 6.6 MB 81.3 MB/s eta 0:00:01
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=79e9eab28af9e971c972f005371bc9b53b5f212cff1b0803d245916dce402eb3
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built sacremoses
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...
#      |████████████████████████████████| 15.2 MB 15.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 462 kB 90.0 MB/s eta 0:00:01
# ...

# %%
# Setting directory
cd /content/drive/MyDrive/AI-based_industry_classification/kerry/Github_ver
# Out:
# /content/drive/MyDrive/AI-based_industry_classification/kerry/Github_ver

# %%
# Make dataset
# !python data/preprocess.py
# Out:
# 2022-04-16 10:35:25.982753: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
#
# Preprocessing Train Data...
# 100% 1000000/1000000 [00:50<00:00, 19806.09it/s]
# 100% 1000000/1000000 [00:51<00:00, 19360.30it/s]
# 100% 1000000/1000000 [00:50<00:00, 19984.13it/s]
# 100% 675012/675012 [00:16<00:00, 39936.36it/s]
# 100% 675012/675012 [00:17<00:00, 39364.57it/s]
# 100% 675012/675012 [00:17<00:00, 38598.15it/s]
# 100% 675012/675012 [00:46<00:00, 14650.83it/s]
#
# => Train Data saved at train_final_spacing.csv
#
# Preprocessing Test Data...
# 100% 100000/100000 [00:04<00:00, 22729.07it/s]
# 100% 100000/100000 [00:04<00:00, 20889.98it/s]
# 100% 100000/100000 [00:04<00:00, 22311.47it/s]
# 100% 99473/99473 [00:02<00:00, 40969.67it/s]
# 100% 99473/99473 [00:02<00:00, 39358.16it/s]
# 100% 99473/99473 [00:02<00:00, 39936.23it/s]
#
# ...

# %%
# Training 5-fold models
# !python main.py --train 'True'
# Out:
# ====== Input arguments ======
# argparse{
#  	 train : True
# 	 model_name : klue/bert-base
# 	 weight_path : weights/
# 	 sub_path : sub/
# 	 path_to_train_data : data/train_final_spacing.csv
# 	 path_to_test_data : data/test_final_spacing.csv
# 	 device : cuda
# 	 batch_size : 64
# 	 max_epochs : 4
# 	 max_len : 35
# 	 learning_rate : 2e-05
# 	 weight_decay : 0.01
# 	 dropout : 0.1
# 	 digit_1_class : 19
# 	 digit_2_class : 74
# 	 digit_3_class : 225
# }
# [<torch.utils.data.dataloader.DataLoader object at 0x7f4621346c10>, <torch.utils.data.dataloader.DataLoader object at 0x7f46213467d0>, <torch.utils.data.dataloader.DataLoader object at 0x7f4621346650>, <torch.utils.data.dataloader.DataLoader object at 0x7f46213464d0>, <torch.utils.data.dataloader.DataLoader object at 0x7f4621346350>]
# ...

# %%
# Inference with 5-fold models, make and save average ensemble logits
# !python main.py --train 'False'
# Out:
# ====== Input arguments ======
# argparse{
#  	 train : False
# 	 model_name : klue/roberta-large
# 	 weight_path : weights/
# 	 sub_path : sub/
# 	 path_to_train_data : data/train_final_spacing.csv
# 	 path_to_test_data : data/test_final_spacing.csv
# 	 device : cuda
# 	 batch_size : 64
# 	 max_epochs : 4
# 	 max_len : 55
# 	 learning_rate : 2e-05
# 	 weight_decay : 0.01
# 	 Tmax : 4
# 	 dropout : 0.1
# 	 digit_1_class : 19
# 	 digit_2_class : 74
# 	 digit_3_class : 225
# }
# Some weights of the model checkpoint at klue/roberta-large were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...
